# %% [markdown]
# ### Target
#
# ![](http://r-statistics.co/screenshots/ggplot_masterlist_4.png)

# %%
import pandas as pd
mpg= pd.read_csv("http://goo.gl/uEeRGu")

# %%
from altair import *
chart = Chart(mpg)
chart.mark_circle().encode(
    y=Y('hwy'),
    x='cty',
)
# Out:
# <div class="vega-embed" id="a656ba97-d54c-4559-8d03-dc0e2789d641"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# Todo
#
# 1. Add jitter?
