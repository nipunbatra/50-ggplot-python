# %% [markdown]
# ### Target
#
# ![](http://r-statistics.co/screenshots/ggplot_masterlist_5.png)

# %%
import pandas as pd
mpg= pd.read_csv("http://goo.gl/uEeRGu")

# %%
from altair import *
chart = Chart(mpg)
chart.mark_circle(color='red').encode(
    y=Y('count(hwy)'),
    x='cty',
)
# Out:
# <div class="vega-embed" id="d401a0c7-f608-4f5f-b802-67a455758868"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# Todo
#
# 1. The plot looks very different. Am I doing something wrong?
