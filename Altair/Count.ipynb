# %% [markdown]
# ### Target
#
# ![](http://r-statistics.co/screenshots/ggplot_masterlist_5.png)

# %%
import pandas as pd
mpg= pd.read_csv("http://goo.gl/uEeRGu")

# %%
from altair import *
chart = Chart(mpg)
chart.mark_circle().encode(
    y=Y('count(hwy)'),
    x='cty',
)
# Out:
# <div class="vega-embed" id="54822910-a4f6-4741-9756-fc0014bb57f3"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# Todo
#
# 1. How to add the tomato3 color?
# 2. The plot looks very different. Am I doing something wrong?
