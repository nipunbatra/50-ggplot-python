# %% [markdown]
# ### Target
#
# ![](http://r-statistics.co/screenshots/ggplot_masterlist_5.png)

# %%
import pandas as pd
mpg= pd.read_csv("http://goo.gl/uEeRGu")

# %%
from altair import *
chart = Chart(mpg)
chart.mark_circle(color='#CD4F39').encode(
    y=Y('hwy'),
    x=X('cty'),
    size='count(*)'
)
# Out:
# <div class="vega-embed" id="09c2dfd3-0ec6-4cce-b192-6546ac22d5cf"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# Todo
#
# 1. The plot looks somewhat different. Am I doing something wrong? The original plot says: Whereever there is more points overlap, the size of the circle gets bigger.
