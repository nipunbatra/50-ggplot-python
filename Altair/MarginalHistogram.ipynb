# %% [markdown]
# ### Target
#
# ![](http://r-statistics.co/screenshots/ggplot_masterlist_8_1.png)

# %%
import pandas as pd
mpg= pd.read_csv("http://goo.gl/uEeRGu")

# %%
from altair import *
chart = Chart(mpg)
chart.mark_bar().encode(
    y='count(*)',
    x=X('cty', bin=Bin(
            maxbins=10.0, step=1
        ))
)
# Out:
# <div class="vega-embed" id="88dbf520-9c34-4cf2-b36b-268cfb47b1b0"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# Todo
#
# 1. Can individually make the 2 histograms and the scatter. How to combine the three and ofcourse rotating one of the histograms by 90 degrees.
