# %% [markdown]
# ### Target
#
# ![](http://r-statistics.co/screenshots/ggplot_masterlist_1.png)

# %%
import pandas as pd
midwest= pd.read_csv("http://goo.gl/G1K41K")

# %%
from altair import *
X()
chart = Chart(midwest)
chart.mark_circle().encode(
    x=X('area', title='Area'),
    y=Y('poptotal', title='Population'),
    color=Color('state'),
    size='popdensity',
).transform_data(filter = (expr.df.poptotal<50000)).configure(numberFormat='0.2f')
# Out:
# <div class="vega-embed" id="5c5892f8-2c1f-40e9-84b0-a23d8b9387b6"></div>
#
# <style>
# .vega-embed svg, .vega-embed canvas {
#   border: 1px dotted gray;
# }
#
# .vega-embed .vega-actions a {
#   margin-right: 6px;
# }
# </style>

# %% [markdown]
# Todo
#
# 1. Add smoothing line? Does Vega support it yet?
# 3. No way to set title?
# 4. No way to set caption?
